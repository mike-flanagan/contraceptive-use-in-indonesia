# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import pandas_datareader.data as web
import requests
import yfinance as yf
from alpha_vantage.timeseries import TimeSeries
import time
import datetime
import matplotlib as plt
import seaborn as sns
from td.client import TDClient
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import SelectKBest, f_regression, mutual_info_regression
from sklearn.feature_selection import RFECV
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
# from code.functions import *
# %matplotlib inline

# %%
pd.set_option('display.max_columns',None)

# %%
# csv_filepath = f'data/{ticker}_intra_Mar_15_26.csv'

# %%
df = pd.read_csv('data/cmc.data', names = ['age','ed','hus_edu','chil','rel','work',
                                        'hus_ocu','sol','media','cm'])

# %%
def dummify(features, to_dummy):
    df_subset = df[features]
    
    if len(to_dummy) > 0:
        for feature in to_dummy:
            df_dummy = pd.get_dummies(df[feature])
            try: # check if column already dropped
                df_subset = df_subset.drop(feature, axis = 1)
            except :
#                 print('Column already removed.')
                next
            df_train = pd.concat([df_subset,df_dummy], axis = 1)
    else:
        df_train = df_subset
        
    return df_train

# %%
sns.pairplot(cmc)

# %%
df.isna().sum()
# Out:
# age        0
# ed         0
# hus_edu    0
# chil       0
# rel        0
# work       0
# hus_ocu    0
# sol        0
# media      0
# cm         0
# dtype: int64

# %%
df.cm.value_counts()
# Out:
# 1    629
# 3    511
# 2    333
# Name: cm, dtype: int64

# %% [markdown]
# Questions:
# ad spending or government spending on health education, to better target demographics who are not likely to use short or long-term contraceptive methods
# each row represents a person
# target variable is contraceptive method

# %%
data.to_csv(csv_filepath, mode='w')

# %%
csv_write(ticker, data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-a1add05df81a> in <module>
# ----> 1 csv_write(ticker, data)
#
# NameError: name 'csv_write' is not defined

# %% [markdown]
# # EDA

# %% [markdown]
# # Feature Engineering

# %%
X = df
y = df.pop('cm')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cm'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-054965ae0fdb> in <module>
#       1 X = df
# ----> 2 y = df.pop('cm')
#
# ...

# %%
to_dummy = ['edu', 'hus_edu', 'chil', 'hus_ocu', 'sol']
features = df.columns
log_reg(dummify(features, to_dummy))

# %%
keep age continuous
create new variable 18 or younger

# %% [markdown]
# # Modeling

# %%
def log_reg(X, y):
    # Split data into train and test sets
    X_train, X_test, y_train, y_test = \
        train_test_split(X, y, test_size=.25,
                         random_state=1)
    
    # Scale the data for modeling
    log_scaler = StandardScaler()
    log_scaler.fit(X_train)
    X_train_sc = log_scaler.transform(X_train)
    X_test_sc = log_scaler.transform(X_test)
    
    # Train a logistic regression model with the train data
    log_model = LogisticRegression(random_state=20)
    
#                                    solver='liblinear',
#                                    C=.001,
#                                    class_weight = 'balanced')
    log_model.fit(X_train_sc, y_train)
    y_pred = cred_model.predict(X_test_sc)
    model_stats(X.columns, model, X_test_sc, y_test, y_pred)
    return

# %%
def model_stats(features, model, X_test_sc, y_test, y_pred):
    print('Num features: ', features.size)
    print('Model score: ', model.score(X_test_sc, y_test))
    print('Model F1: ', f1_score(y_test, y_pred))
    print('Cross validation score: ', cross_val_score(model, X_test_sc, y_test, cv=5) )
    print('Classification Report:')
    print(classification_report(y_test, y_pred))
    fig, ax = plt.subplots(2,1, figsize = [6,8])
    plot_confusion_matrix(model, X_test_sc, y_test, ax = ax[0])
    plot_roc_curve(model, X_test_sc, y_test, ax = ax[1])

# %%
logreg_model_final = LogisticRegression()
