# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, GridSearchCV,\
    cross_val_score
from sklearn.metrics import SCORERS
# from imblearn.under_sampling import TomekLinks
from sklearn.decomposition import PCA
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
# from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier, XGBRFClassifier
import sys
sys.path.insert(0, '../code')
from functions import *
import warnings; warnings.simplefilter('ignore')
warnings.filterwarnings('ignore');
# %matplotlib inline

# %% [markdown]
# # EDA

# %% [markdown]
# ## Load Data

# %%
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv('../data/cmc.data', names = ['age','edu','hus_edu','chil','rel','work',
                                        'hus_ocu','sol','media','cmc'])

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# This notebook was prepared using the original features only, and using multiclass estimators

# %% [markdown]
# ## Dummying, Scaling/Fit/Transform

# %%
X = df.copy()
y = X.pop('cmc')
to_dummy = ['edu', 'hus_edu', 'chil', 'hus_ocu', 'sol']
X_with_dums = pd.get_dummies(X, columns=to_dummy, drop_first=True)
# X_with_dums.shape
X_train_df, X_test, y_train, y_test = train_test_split(
    X_with_dums, y, test_size=.25,
    random_state=1)
# X_train.shape
rs = RobustScaler()
rs.fit(X_train_df)
X_train = rs.transform(X_train_df)
X_test = rs.transform(X_test)

# %% [markdown]
# # Models

# %% [markdown]
# Best models from models fitted in 'model_fitting_and_tuning.ipynb':
#
# LogisticRegresion
# XGBClassifier

# %% [markdown]
# # Predicting on new data

# %%
columns_1987 = ['v012', 'v106', 'v701', 'v201', 'v130', 'v714', 'v705', 'v109', 'v110', 'v111', 'v312']
columns_2017 = ['v012', 'v106', 'v701', 'v201', 'v130', 'v714', 'v705', 'v157', 'v158', 'v159', 'v312']
cmc_map = {'not using':'1', 'iud':'2', 'pill':'3', 'injections':'3', 'female sterilization':'2', 'condom':'3',
           'periodic abstinence':'3', 'withdrawal':'3', 'jamu jamu (herbs)':'3', 'abstinence':'3', 'norplant':'2',
           'pijat (massage)':'3', 'male sterilization':'2', 'other':'3', 'diaphragm /foam/jelly':'3',
           'injections 3 month':'3', 'injection 1 months':'3', 'implants/norplant':'2', 'other traditional':'3',
           'lactational amenorrhea (lam)':'3', 'other modern method':'3', 'male condom':'3'}
# rel_map = {'muslim':1, 'hindu':0, 'protestant /christian':0, 'catholic':0, 'buddhist':0, 'other':0}
ocu_map = {'agriculture':'4', 'manual':'3', 'sales, services':'2', 'prof, tech, cleric.':'1', 'never worked':'5',
          'other':'5', 'dont know':'5', 'agricultural - self employed':'4', 'industrial worker':'3', 'services':'2',
          'sales':'2', 'professional/technical/managerial':'1', 'clerical':'1', 'did not work':'5', 'don\'t know':'5'}

# %% [markdown]
# ## Load full 1987 Data

# %%
df_1987_ir = pd.read_stata('../data/ID_1987_DHS_04012021_1716_161452/IDIR01DT/IDIR01FL.DTA', columns = columns_1987)
df_1987_ir.dropna(subset=['v312'], inplace=True)
# df_1987_ir.dropna(subset=['v130'], inplace=True)
df_1987_ir.drop(columns=['v130'], inplace=True)
df_1987_ir.shape
# Out:
# (11883, 10)

# %%
# ['age','edu','hus_edu','chil','rel','work', 'hus_ocu','sol','media','cmc']

# %%
df_1987_ir.head()
# Out:
#    v012       v106       v701  v201 v714                 v705 v109 v110 v111  \
# 0    41  secondary    primary     6  yes          agriculture   no   no  yes
# 1    27  secondary  secondary     5   no  prof, tech, cleric.  yes  yes   no
# 2    43  secondary  secondary     8   no      sales, services  yes  yes   no
# 3    41    primary  secondary     9  yes  prof, tech, cleric.   no  yes  yes
# 4    29  secondary  secondary     3   no          agriculture  yes  yes  yes
#
#         v312
# 0  not using
# 1  not using
# 2  not using
# 3  not using
# 4  not using

# %%
conditions = [(df_1987_ir.v109 == 'yes'), 
              (df_1987_ir.v110 == 'yes'),
              (df_1987_ir.v111 == 'yes')           
]

choices = [1, 1, 1]

df_1987_ir['vmed'] = np.select(conditions, choices, 0)
df_1987_ir.vmed.value_counts()
# Out:
# 1    9407
# 0    2476
# Name: vmed, dtype: int64

# %%
df_1987_ir.v312 = df_1987_ir.v312.map(cmc_map)
# df_1987_ir.v130 = df_1987_ir.v130.map(rel_map)
df_1987_ir.v312.value_counts()
# Out:
# 1    6267
# 3    3256
# 2    2360
# Name: v312, dtype: int64

# %%
df_1987_ir.v705 = df_1987_ir.v705.map(ocu_map)
df_1987_ir.v705.value_counts()
# Out:
# 4    4858
# 3    2943
# 2    2106
# 1    1847
# 5     127
# Name: v705, dtype: int64

# %%
df_1987_ir['uses_cm'] = np.where(df_1987_ir.v312 == '1', # mapping multiclass target to a boolean Yes/No value
                            0,
                            1)

# %%
X_1987 = df_1987_ir.copy()
y_1987 = X_1987.pop('uses_cm')
y_1987 = y_1987.astype(int)
X_1987.v201 = X_1987.v201.astype(object)
X_1987.vmed = X_1987.vmed.astype(object)
X_1987.drop(columns = ['v109','v110','v111','v312'], inplace = True)

# %%
X_1987.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11883 entries, 0 to 11883
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v012    11883 non-null  int8
#  1   v106    11883 non-null  category
#  2   v701    11877 non-null  category
#  3   v201    11883 non-null  object
#  4   v714    11867 non-null  category
#  5   v705    11881 non-null  object
#  6   vmed    11883 non-null  object
# dtypes: category(3), int8(1), object(3)
# memory usage: 418.2+ KB

# %%
y_1987.value_counts()
# Out:
# 0    6267
# 1    5616
# Name: uses_cm, dtype: int64

# %% [markdown]
# ## Modeling using LogisticRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_1987, y_1987, test_size=0.25, random_state=729)

# train set
X_train_nums = X_train.select_dtypes('int8')
rs = RobustScaler()
# ss = StandardScaler()
rs.fit(X_train_nums)
nums_df = pd.DataFrame(rs.transform(X_train_nums),
                      index=X_train_nums.index)

X_train_cat = X_train.select_dtypes(['category','object'])
ohe = OneHotEncoder(
    #drop='first',
    handle_unknown='ignore',
    sparse=False)
dums = ohe.fit_transform(X_train_cat)
dums_df = pd.DataFrame(dums,
                       columns=ohe.get_feature_names(),
                       index=X_train_cat.index)

X_train_clean = pd.concat([nums_df,
                 dums_df], axis=1)
# test set
X_test_nums = X_test.select_dtypes('int8')
nums_df = pd.DataFrame(rs.transform(X_test_nums),
                      index=X_test_nums.index)

X_test_cat = X_test.select_dtypes(['category','object'])
dums_df = pd.DataFrame(ohe.transform(X_test_cat),
                       columns=ohe.get_feature_names(),
                       index=X_test_cat.index)
X_test_clean = pd.concat([nums_df,
                 dums_df], axis=1)

new_pipe_lr = Pipeline([('lr', LogisticRegression(random_state=1, max_iter=200))])

params_grid_new_lr = {'lr__penalty' : ['l2'],
                  'lr__class_weight' : ['balanced'],
                  'lr__dual' : [True],
                  'lr__solver' : ['liblinear'],
                  'lr__C' : np.logspace(-4, 4, 20),
                  'lr__l1_ratio' : np.logspace(-4, 4, 20) # only needed for elasticnet
                     }

new_lr_clf = GridSearchCV(new_pipe_lr, param_grid = params_grid_new_lr,
                       cv = 3, verbose=0, n_jobs=-1, scoring='recall')

new_lr_clf.fit(X_train_clean, y_train)
print(new_lr_clf.best_params_)
best_new_lr_clf = new_lr_clf.best_estimator_
model_stats(X_train_clean.columns, best_new_lr_clf, 'LogisticRegression', X_test_clean, y_test, True)
# Out:
# {'lr__C': 206.913808111479, 'lr__class_weight': 'balanced', 'lr__dual': True, 'lr__l1_ratio': 0.0001, 'lr__penalty': 'l2', 'lr__solver': 'liblinear'}
# Classifier:  LogisticRegression
# Num features:  39
# Model score:  0.6418714237630427
# Accuracy score:  0.6418714237630427
# Model F1 (micro):  0.6418714237630427
# Model F1 (macro):  0.6408297420784181
# Model F1 (weighted):  0.6401461384728833
# Cross validation score:  [0.62910008 0.60639193 0.61952862 0.58838384 0.56649832]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.57      0.62      3076
#            1       0.61      0.72      0.66      2866
#
#     accuracy                           0.64      5942
#    macro avg       0.65      0.64      0.64      5942
# weighted avg       0.65      0.64      0.64      5942

# %% [markdown]
# ### Applying weighting to Negative Class (no contraception)

# %%
new_pipe_lr = Pipeline([('lr', LogisticRegression(random_state=1, max_iter=200))])

params_grid_new_lr = {'lr__penalty' : ['l2'],
                  'lr__class_weight' : [{0:100, 1:1}],
                  'lr__dual' : [True],
                  'lr__solver' : ['liblinear'],
                  'lr__C' : np.logspace(-4, 4, 20),
                  'lr__l1_ratio' : np.logspace(-4, 4, 20) # only needed for elasticnet
                     }

new_lr_clf = GridSearchCV(new_pipe_lr, param_grid = params_grid_new_lr,
                       cv = 3, verbose=0, n_jobs=-1, scoring='recall')

new_lr_clf.fit(X_train_clean, y_train)
print(new_lr_clf.best_params_)
best_new_lr_clf = new_lr_clf.best_estimator_
model_stats(X_train_clean.columns, best_new_lr_clf, 'LogisticRegression', X_test_clean, y_test, True)
# Out:
# {'lr__C': 10000.0, 'lr__class_weight': {0: 100, 1: 1}, 'lr__dual': True, 'lr__l1_ratio': 0.0001, 'lr__penalty': 'l2', 'lr__solver': 'liblinear'}
# Classifier:  LogisticRegression
# Num features:  39
# Model score:  0.5831369909121508
# Accuracy score:  0.5831369909121508
# Model F1 (micro):  0.5831369909121508
# Model F1 (macro):  0.5765155919317664
# Model F1 (weighted):  0.5783870505937861
# Cross validation score:  [0.57947855 0.53490328 0.54377104 0.52777778 0.52020202]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.58      0.68      0.63      3076
#            1       0.58      0.47      0.52      2866
#
#     accuracy                           0.58      5942
#    macro avg       0.58      0.58      0.58      5942
# weighted avg       0.58      0.58      0.58      5942

# %% [markdown]
# ### Setting GridSearchCV to default scoring

# %%
new_pipe_lr = Pipeline([('lr', LogisticRegression(random_state=1, max_iter=200))])

params_grid_new_lr = {'lr__penalty' : ['l2'],
                  'lr__class_weight' : [{0:100, 1:1}],
                  'lr__dual' : [True],
                  'lr__solver' : ['liblinear'],
                  'lr__C' : np.logspace(-4, 4, 20),
                  'lr__l1_ratio' : np.logspace(-4, 4, 20) # only needed for elasticnet
                     }

new_lr_clf = GridSearchCV(new_pipe_lr, param_grid = params_grid_new_lr,
                       cv = 3, verbose=0, n_jobs=-1)

new_lr_clf.fit(X_train_clean, y_train)
print(new_lr_clf.best_params_)
best_new_lr_clf = new_lr_clf.best_estimator_
model_stats(X_train_clean.columns, best_new_lr_clf, 'LogisticRegression', X_test_clean, y_test, True)
# Out:
# {'lr__C': 206.913808111479, 'lr__class_weight': {0: 100, 1: 1}, 'lr__dual': True, 'lr__l1_ratio': 0.0001, 'lr__penalty': 'l2', 'lr__solver': 'liblinear'}
# Classifier:  LogisticRegression
# Num features:  39
# Model score:  0.552002692696062
# Accuracy score:  0.552002692696062
# Model F1 (micro):  0.552002692696062
# Model F1 (macro):  0.4962993731639369
# Model F1 (weighted):  0.5022192603611769
# Cross validation score:  [0.56602187 0.52733389 0.52020202 0.51851852 0.51851852]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.85      0.66      3076
#            1       0.59      0.23      0.33      2866
#
#     accuracy                           0.55      5942
#    macro avg       0.57      0.54      0.50      5942
# weighted avg       0.57      0.55      0.50      5942

# %% [markdown]
# ## Comparing against 2017 data as holdout set

# %% [markdown]
# ### Load 2017 dataset and perform feature engineering

# %%
df_2017_ir = pd.read_stata('../data/ID_2017_DHS_04012021_1713_161452/IDIR71DT/IDIR71FL.DTA', columns = columns_2017)
df_2017_ir.drop(columns=['v130'], inplace=True)
df_2017_ir.dropna(subset=['v701','v714','v705', 'v157', 'v158', 'v159'], inplace=True)
# df_1987_ir.dropna(subset=['v130'], inplace=True)
df_2017_ir.shape
# Out:
# (34245, 10)

# %%
df_2017_ir.isna().sum()
# Out:
# v012    0
# v106    0
# v701    0
# v201    0
# v714    0
# v705    0
# v157    0
# v158    0
# v159    0
# v312    0
# dtype: int64

# %%
df_2017_ir.v157.value_counts()
# Out:
# not at all               20174
# less than once a week    10786
# at least once a week      3285
# Name: v157, dtype: int64

# %%
conditions = [df_2017_ir.v157 != 'not at all',
              df_2017_ir.v158 != 'not at all',
              df_2017_ir.v159 != 'not at all']
choices = [1, 1, 1]

df_2017_ir['vmed'] = np.select(conditions, choices, 0)
df_2017_ir.vmed.value_counts()
# Out:
# 1    33046
# 0     1199
# Name: vmed, dtype: int64

# %%
df_2017_ir.v312 = df_2017_ir.v312.map(cmc_map)
df_2017_ir.v312.value_counts()
# Out:
# 3    16328
# 1    13464
# 2     4453
# Name: v312, dtype: int64

# %%
df_2017_ir['uses_cm'] = np.where(df_2017_ir.v312 == '1', # mapping multiclass target to a boolean Yes/No value
                            0,
                            1)
df_2017_ir.uses_cm.value_counts()
# Out:
# 1    20781
# 0    13464
# Name: uses_cm, dtype: int64

# %%
df_2017_ir.v705 = df_2017_ir.v705.map(ocu_map)
df_2017_ir.v705.value_counts()
# Out:
# 2    10150
# 4     9378
# 3     8454
# 1     5419
# 5      844
# Name: v705, dtype: int64

# %%
X_2017 = df_2017_ir.copy()
y_2017 = X_2017.pop('uses_cm')
y_2017 = y_2017.astype(int)
X_2017.v201 = X_2017.v201.astype(object)
X_2017.vmed = X_2017.vmed.astype(object)
X_2017.drop(columns = ['v157','v158','v159','v312'], inplace = True)

# %%
X_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34245 entries, 0 to 49626
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v012    34245 non-null  int8
#  1   v106    34245 non-null  category
#  2   v701    34245 non-null  category
#  3   v201    34245 non-null  object
#  4   v714    34245 non-null  category
#  5   v705    34245 non-null  object
#  6   vmed    34245 non-null  object
# dtypes: category(3), int8(1), object(3)
# memory usage: 1.2+ MB

# %% [markdown]
# ### Transform and predict using fitted LogisticRegression Model

# %% [markdown]
# Using our best performing LogisticRegression estimator from above, we fit it on our 1987 data and run it on our 2017 data to determine model performance.

# %%
X_2017_nums = X_2017.select_dtypes('int8')
nums_df = pd.DataFrame(rs.transform(X_2017_nums),
                      index=X_2017_nums.index)

X_2017_cat = X_2017.select_dtypes(['category','object'])
dums_df = pd.DataFrame(ohe.transform(X_2017_cat),
                       columns=ohe.get_feature_names(),
                       index=X_2017_cat.index)
X_2017_clean = pd.concat([nums_df,
                 dums_df], axis=1)

# %%
model_stats(X_2017_clean.columns, best_new_lr_clf, 'LogisticRegression', X_2017_clean, y_2017, True)
# Out:
# Classifier:  LogisticRegression
# Num features:  39
# Model score:  0.4406482698204117
# Accuracy score:  0.4406482698204117
# Model F1 (micro):  0.4406482698204117
# Model F1 (macro):  0.3909755305270436
# Model F1 (weighted):  0.35381239827657585
# Cross validation score:  [0.6326471  0.63074901 0.57366039 0.4587531  0.48109213]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.41      0.92      0.56     13464
#            1       0.72      0.13      0.22     20781
#
#     accuracy                           0.44     34245
#    macro avg       0.56      0.53      0.39     34245
# weighted avg       0.60      0.44      0.35     34245

# %% [markdown]
# ### Modeling using XGBClassifier with optimal hyperparameters

# %% [markdown]
# Pulling in our best performing XGBClassifer from the 'model_fitting_and_tuning.ipynb' notebook, we fit it on our 1987 data
# and run it on our 2017 data to determine model performance.

# %%
xgb_clf = XGBClassifier(random_state=729, learning_rate = 0.3, eval_metric = 'auc',
                        booster = 'gblinear',
                        colsample_bylevel = 0.25,
                        colsample_bynode = 0.25,
                        colsample_bytree = 0.25,
                        max_depth = 5,
                        min_child_weight = 4,
                        xgbmissing = -999,
                        n_estimators = 500,
                        subsample = 0.05
                       )
xgb_clf.fit(X_train_clean, y_train)
model_stats(X_2017_clean.columns, xgb_clf, 'XGBClassifier', X_2017_clean, y_2017, True)
# Out:
# [15:00:08] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Classifier:  XGBClassifier
# Num features:  39
# Model score:  0.6467805519053876
# Accuracy score:  0.6467805519053876
# Model F1 (micro):  0.6467805519053876
# Model F1 (macro):  0.6343299080473029
# Model F1 (weighted):  0.6487469615541246
# [15:00:11] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:00:13] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:00:16] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:00:18] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:00:21] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Cross validation score:  [0.71572492 0.70842459 0.71207476 0.69542999 0.69250986]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.59      0.57     13464
#            1       0.72      0.68      0.70     20781
#
#     accuracy                           0.65     34245
#    macro avg       0.63      0.64      0.63     34245
# weighted avg       0.65      0.65      0.65     34245

# %% [markdown]
# ### Setting more weight toward Negative Class (no contraception)

# %%
xgb_clf = XGBClassifier(random_state=729, learning_rate = 0.3, eval_metric = 'auc',
                        booster = 'gblinear',
                        colsample_bylevel = 0.25,
                        colsample_bynode = 0.25,
                        colsample_bytree = 0.25,
                        max_depth = 5,
                        min_child_weight = 4,
                        xgbmissing = -999,
                        n_estimators = 500,
                        subsample = 0.05,
                        scale_pos_weight = 0.5
                       )
xgb_clf.fit(X_train_clean, y_train)
model_stats(X_2017_clean.columns, xgb_clf, 'XGBClassifier', X_2017_clean, y_2017, True)
# Out:
# [00:30:47] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Classifier:  XGBClassifier
# Num features:  39
# Model score:  0.4855891371003066
# Accuracy score:  0.4855891371003066
# Model F1 (micro):  0.4855891371003066
# Model F1 (macro):  0.46210794934758537
# Model F1 (weighted):  0.43809511206084023
# [00:30:48] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:30:49] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:30:50] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:30:51] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:30:52] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Cross validation score:  [0.6564462  0.64009344 0.58344284 0.63542123 0.63104103]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.43      0.88      0.57     13464
#            1       0.75      0.23      0.35     20781
#
#     accuracy                           0.49     34245
#    macro avg       0.59      0.56      0.46     34245
# weighted avg       0.62      0.49      0.44     34245

# %% [markdown]
# ### Predict using XGBRFClassifer

# %%
xgb_rf_clf = XGBRFClassifier(random_state=729, learning_rate = 0.3, eval_metric = 'auc',
                        booster = 'gblinear',
                        colsample_bylevel = 0.25,
                        colsample_bynode = 0.25,
                        colsample_bytree = 0.25,
                        max_depth = 5,
                        min_child_weight = 4,
                        xgbmissing = -999,
                        n_estimators = 500,
                        subsample = 0.05,
                       )
xgb_rf_clf.fit(X_train_clean, y_train)
model_stats(X_2017_clean.columns, xgb_rf_clf, 'XGBRFClassifier', X_2017_clean, y_2017, True)
# Out:
# [00:32:54] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, num_parallel_tree, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Classifier:  XGBRFClassifier
# Num features:  39
# Model score:  0.6656738209957658
# Accuracy score:  0.6656738209957658
# Model F1 (micro):  0.6656738209957658
# Model F1 (macro):  0.6374806732789651
# Model F1 (weighted):  0.6590816431055443
# [00:32:54] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, num_parallel_tree, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:32:54] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, num_parallel_tree, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:32:54] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, num_parallel_tree, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:32:54] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, num_parallel_tree, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:32:54] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, num_parallel_tree, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Cross validation score:  [0.68082932 0.67893123 0.67951526 0.67557308 0.67046284]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.59      0.49      0.54     13464
#            1       0.70      0.78      0.74     20781
#
#     accuracy                           0.67     34245
#    macro avg       0.65      0.64      0.64     34245
# weighted avg       0.66      0.67      0.66     34245

# %% [markdown]
# ### Setting more weight toward Negative Class (no contraception)

# %%
xgb_rf_clf = XGBRFClassifier(random_state=729, learning_rate = 0.3, eval_metric = 'auc',
                        booster = 'gblinear',
                        colsample_bylevel = 0.25,
                        colsample_bynode = 0.25,
                        colsample_bytree = 0.25,
                        max_depth = 5,
                        min_child_weight = 4,
                        xgbmissing = -999,
                        n_estimators = 500,
                        subsample = 0.05,
                        scale_pos_weight = 0.75
                       )
xgb_rf_clf.fit(X_train_clean, y_train)
model_stats(X_2017_clean.columns, xgb_rf_clf, 'XGBRFClassifier', X_2017_clean, y_2017, True)
# Out:
# [00:37:37] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, num_parallel_tree, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Classifier:  XGBRFClassifier
# Num features:  39
# Model score:  0.4615564315958534
# Accuracy score:  0.4615564315958534
# Model F1 (micro):  0.4615564315958534
# Model F1 (macro):  0.425563960646182
# Model F1 (weighted):  0.3948410360149704
# [00:37:37] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, num_parallel_tree, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:37:37] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, num_parallel_tree, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:37:37] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, num_parallel_tree, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:37:37] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, num_parallel_tree, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [00:37:37] WARNING: ../src/learner.cc:541:
# Parameters: { colsample_bylevel, colsample_bynode, colsample_bytree, max_depth, min_child_weight, num_parallel_tree, subsample, xgbmissing } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Cross validation score:  [0.68637757 0.67922324 0.69017375 0.67075485 0.6761571 ]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.42      0.91      0.57     13464
#            1       0.74      0.17      0.28     20781
#
#     accuracy                           0.46     34245
#    macro avg       0.58      0.54      0.43     34245
# weighted avg       0.61      0.46      0.39     34245
